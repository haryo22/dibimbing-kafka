# %%
import json
import uuid
import os
from dotenv import load_dotenv
from pathlib import Path
from kafka import KafkaProducer
from faker import Faker
from time import sleep

# %%
dotenv_path = Path('/resources/.env')
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
kafka_host = os.getenv('KAFKA_HOST')
kafka_topic = os.getenv('KAFKA_TOPIC_NAME')
kafka_topic_partition = os.getenv('KAFKA_TOPIC_NAME')

print(kafka_host)
print(kafka_topic)
print(kafka_topic_partition)
# Out:
# dataeng-kafka
# kafka-assignment24
# kafka-assignment24

# %%
producer = KafkaProducer(bootstrap_servers=f'{kafka_host}:9092')

# %%
_instance = Faker()
global faker
faker = Faker()

# %%
class DataGenerator(object):
    @staticmethod
    def get_data():
        quality = faker.random_int(min=1, max=20)
        unit_price = faker.random_int(min=100000, max=1000000)
        total_price = quality * unit_price

        transaction_date = faker.date_this_year().strftime('%Y-%m-%d')

        return [
            uuid.uuid4().__str__(),
            faker.name(),
            faker.random_element(elements=('Toko Mainan Pokemon Jakarta', 'Pokemon Shop Surabaya', 'Pokemon Toys Yogyakarta', 'Mainan Pokemon Bandung', 'Pokemon Collector Semarang')),
            faker.random_element(elements=('Jakarta', 'Surabaya', 'Bandung', 'Yogyakarta', 'Semarang', 'Medan', 'Makassar')),
            faker.random_element(elements=('Kartu Pokemon', 'Action Figure Pikachu', 'Pokemon Plush', 'Pokemon Ball', 'Mainan Pokemon Model')),
            faker.random_element(elements=('Kartu Pokemon Base Set', 'Pokemon Sword & Shield', 'Eevee Plush', 'Pikachu Action Figure', 'Poké Ball Replica')),
            faker.random_element(elements=('Cash', 'Credit Card', 'Debit Card', 'QRIS', 'Transfer')),
            faker.random_element(elements=('Blibli', 'Offline', 'Lazada', 'Shopee', 'Tokopedia')),
            quality,
            unit_price,
            total_price,
            transaction_date
        ]

# %%
for i in range(1, 200):
    columns = ["transaction_id", "customer_name", "store_name", "location", "product_type", "product_model", "payment", "merchant", "quantity", "unit_price", "total_price", "transaction_date"]
    data_list = DataGenerator.get_data()
    json_data = dict(zip(columns, data_list))
    _payload = json.dumps(json_data).encode("utf-8")
    response = producer.send(topic=kafka_topic_partition, value=_payload)
    print(json_data['transaction_id'], response.get())

sleep(5)
# Out:
# d3533f92-ce97-4124-b55a-a33afcbc1cf5 RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=999, timestamp=1737731070338, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=377, serialized_header_size=-1)
# 646a7627-ba43-40f6-ab52-b5fef57f2a17 RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=990, timestamp=1737731070344, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# f452c2be-3dc4-4f89-87f3-08e2d851639f RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=991, timestamp=1737731070346, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=377, serialized_header_size=-1)
# 0b0db2ae-834d-45c7-adb1-bb2b314fd039 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1003, timestamp=1737731070347, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=383, serialized_header_size=-1)
# 509d8e6f-abcb-4366-adb4-0ae8784863c7 RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=992, timestamp=1737731070350, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
# c3013ad6-6ea5-4a47-a7bd-56f1fd98dc27 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1004, timestamp=1737731070351, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=374, serialized_header_size=-1)
# 2c1c9d55-a2b5-47c5-93a9-636e1320282f RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=993, timestamp=1737731070352, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# 37fceb20-da68-4420-a906-e7b60eb0ee7d RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1005, timestamp=1737731070354, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=375, serialized_header_size=-1)
# c75a79de-9617-4ff7-bf50-b630ff158888 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1006, timestamp=1737731070355, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=386, serialized_header_size=-1)
# 5678c15c-60a5-45ea-b948-c0c36701103f RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1007, timestamp=1737731070356, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1051, timestamp=1737731070601, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# 8302e51c-b0e5-4173-adc0-5520939253ce RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1051, timestamp=1737731070602, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=379, serialized_header_size=-1)
# 6de08a88-a067-47fc-b827-90ea979a8a98 RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1052, timestamp=1737731070603, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=384, serialized_header_size=-1)
# 48da5421-73a6-4ac7-9d0e-1d4333b8f772 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1064, timestamp=1737731070604, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=378, serialized_header_size=-1)
# b05c1afd-2cc9-4936-a92c-5c07a9c7c66c RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1065, timestamp=1737731070605, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=383, serialized_header_size=-1)
# 9c412fc4-b5e4-4ba9-a321-e8da924a1be6 RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1053, timestamp=1737731070606, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=383, serialized_header_size=-1)
# a31fa456-e667-4a2a-88db-1a4c27f1e346 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1066, timestamp=1737731070607, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=378, serialized_header_size=-1)
# 0d6d5e77-b705-4d02-8468-fe170b60f18f RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1052, timestamp=1737731070608, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=380, serialized_header_size=-1)
# a60a8d9d-39db-4fa5-b9a7-3eeb75a20fb8 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1067, timestamp=1737731070611, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
# a4f99a37-b6c0-492a-83ae-8cf0b0c5b2cb RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1054, timestamp=1737731070613, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# 7314aaf1-3f27-4aaa-ba3e-35b39c563ed0 RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1053, timestamp=1737731070614, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# 5e3385db-9ae6-4527-847e-094f01bed517 RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1054, timestamp=1737731070616, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=371, serialized_header_size=-1)
# cfaf65e4-1bb6-40a6-9b7b-7a157a4583b2 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1068, timestamp=1737731070617, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=389, serialized_header_size=-1)
# db801469-5368-4caf-868a-a782bb8263ac RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1055, timestamp=1737731070619, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# 0adce8f5-30c0-4919-ba80-51d6429db727 RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1055, timestamp=1737731070620, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=385, serialized_header_size=-1)
# a1040797-fcb1-499b-81d8-46360b846d96 RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1056, timestamp=1737731070621, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=382, serialized_header_size=-1)
# f51b4d61-2af1-404b-9d85-2f08a14a060c RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1056, timestamp=1737731070622, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=386, serialized_header_size=-1)
# 999919cc-2ae7-4228-affd-1fc9bbe2af26 RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1057, timestamp=1737731070623, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# 84cb7081-0d48-4b1d-a11e-3963ac9f0d85 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1069, timestamp=1737731070624, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=376, serialized_header_size=-1)
# a8de1819-4f54-4541-aa6d-3731d216e4a8 RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1057, timestamp=1737731070626, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# 10ede5c0-53e9-4499-8883-26e0471494da RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1058, timestamp=1737731070627, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=375, serialized_header_size=-1)
# 7d2411ae-e275-4a35-99d5-310474d93697 RecordMetadata(topic='kafka-assignment24', partition=0, topic_partition=TopicPartition(topic='kafka-assignment24', partition=0), offset=1070, timestamp=1737731070629, log_start_offset=1003, checksum=None, serialized_key_size=-1, serialized_value_size=382, serialized_header_size=-1)
# 63ebdfe5-b0fd-4a33-90fc-d216f834b1f3 RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1058, timestamp=1737731070630, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=376, serialized_header_size=-1)
# 9254c3f9-0a26-45a5-a884-33c3184921bf RecordMetadata(topic='kafka-assignment24', partition=1, topic_partition=TopicPartition(topic='kafka-assignment24', partition=1), offset=1059, timestamp=1737731070631, log_start_offset=999, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
# b6b4bd62-3e32-4019-96d6-6eac98206546 RecordMetadata(topic='kafka-assignment24', partition=2, topic_partition=TopicPartition(topic='kafka-assignment24', partition=2), offset=1059, timestamp=1737731070632, log_start_offset=990, checksum=None, serialized_key_size=-1, serialized_value_size=372, serialized_header_size=-1)
